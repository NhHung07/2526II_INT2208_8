# %%
def classify_triangle(a, b, c):
    """
    Phân loại tam giác dựa trên độ dài 3 cạnh.
    
    Args:
        a, b, c: Độ dài 3 cạnh của tam giác
        
    Returns:
        str: "Invalid Input", "Not a Triangle", "Equilateral", "Isosceles", hoặc "Scalene"
    """
    # Kiểm tra tính hợp lệ của dữ liệu đầu vào
    if not isinstance(a, int) or not isinstance(b, int) or not isinstance(c, int):
        return "Invalid Input"
    
    if a < 1 or a > 100 or b < 1 or b > 100 or c < 1 or c > 100:
        return "Invalid Input"
    
    # Kiểm tra xem có phải là tam giác hợp lệ
    if not (a + b > c and a + c > b and b + c > a):
        return "Not a Triangle"
    
    # Phân loại tam giác
    if a == b and b == c:
        return "Equilateral"
    elif a == b or b == c or a == c:
        return "Isosceles"
    else:
        return "Scalene"

# %%
# Test cases
test_cases = [
    # Invalid Input
    (0, 50, 50, "Invalid Input"),  
    (101, 50, 50, "Invalid Input"),  
    (50, 0, 50, "Invalid Input"),  
    (50, 101, 50, "Invalid Input"),  
    (50, 50, 0, "Invalid Input"),  
    (50, 50, 101, "Invalid Input"),  

    # Not a Triangle
    (10, 20, 50, "Not a Triangle"),  
    (1, 2, 3, "Not a Triangle"),    
    
    # Equilateral
    (1, 1, 1, "Equilateral"),
    (50, 50, 50, "Equilateral"),
    (100, 100, 100, "Equilateral"),
    
    # Isosceles
    (50, 50, 36, "Isosceles"),
    (50, 36, 50, "Isosceles"),
    (36, 50, 50, "Isosceles"),
    
    # Scalene
    (3, 4, 5, "Scalene"),
    (98, 99, 100, "Scalene"),
]

# Chạy test
print("Testing Triangle Classification Module\n")
print("=" * 60)
passed = 0
failed = 0

for a, b, c, expected in test_cases:
    result = classify_triangle(a, b, c)
    status = "✓ PASS" if result == expected else "✗ FAIL"
    
    if result == expected:
        passed += 1
    else:
        failed += 1
    
    print(f"{status}: classify_triangle({a}, {b}, {c}) = {result} (expected: {expected})")

print("=" * 60)
print(f"Results: {passed} passed, {failed} failed out of {len(test_cases)} tests")
# Out:
# Testing Triangle Classification Module
#
# ============================================================
# ✓ PASS: classify_triangle(0, 50, 50) = Invalid Input (expected: Invalid Input)
# ✓ PASS: classify_triangle(101, 50, 50) = Invalid Input (expected: Invalid Input)
# ✓ PASS: classify_triangle(50, 0, 50) = Invalid Input (expected: Invalid Input)
# ✓ PASS: classify_triangle(50, 101, 50) = Invalid Input (expected: Invalid Input)
# ✓ PASS: classify_triangle(50, 50, 0) = Invalid Input (expected: Invalid Input)
# ✓ PASS: classify_triangle(50, 50, 101) = Invalid Input (expected: Invalid Input)
# ✓ PASS: classify_triangle(10, 20, 50) = Not a Triangle (expected: Not a Triangle)
# ✓ PASS: classify_triangle(1, 2, 3) = Not a Triangle (expected: Not a Triangle)
# ✓ PASS: classify_triangle(1, 1, 1) = Equilateral (expected: Equilateral)
# ✓ PASS: classify_triangle(50, 50, 50) = Equilateral (expected: Equilateral)
# ✓ PASS: classify_triangle(100, 100, 100) = Equilateral (expected: Equilateral)
# ✓ PASS: classify_triangle(50, 50, 36) = Isosceles (expected: Isosceles)
# ✓ PASS: classify_triangle(50, 36, 50) = Isosceles (expected: Isosceles)
# ✓ PASS: classify_triangle(36, 50, 50) = Isosceles (expected: Isosceles)
# ✓ PASS: classify_triangle(3, 4, 5) = Scalene (expected: Scalene)
# ✓ PASS: classify_triangle(98, 99, 100) = Scalene (expected: Scalene)
# ============================================================
# Results: 16 passed, 0 failed out of 16 tests
